# %%
import pandas as pd
import numpy as np
from itertools import combinations
from nlp_funcs import load_glove, tokenizer, wv_centroid, wv_dis

# %% [markdown]
# ## Import Data

# %%
df = pd.read_csv('/Users/lidanyang/Desktop/intensional-and-extensional-category-convergence/data/final_def_data_FULL.csv', encoding='cp1252', na_values=['nan'])
df.head()
# Out:
#    N  instance_id  label  node_id  total_success  success_rate  \
# 0  2          400  space    15245             44      1.000000
# 1  2          400  space    15414             44      1.000000
# 2  2          400   wide    15245             16      0.888889
# 3  2          400   wide    15414             16      0.888889
# 4  2          400      x    15245             20      0.833333
#
#    label_freq_rank                                  definition  \
# 0                1                                         Gap
# 1                1            A gap within a continuous object
# 2                3                                     Lengthy
# 3                3  A shape that spans furthest left to right.
# 4                2                                       Cross
#
#    raw_image_breadth  norm_image_breadth  num_imgs  min_img  max_img  \
# 0              16030               16030        22      996     1393
# 1              16030               16030        22      996     1393
# 2              31482               31482         8       61      685
# 3              31482               31482         8       61      685
# 4             162606               86604        10       31      909
#
#    num_adopters  prop_adopters
# 0             2            1.0
# 1             2            1.0
# 2             2            1.0
# 3             2            1.0
# 4             2            1.0

# %%
df.describe()
# Out:
#                  N  instance_id       node_id  total_success  success_rate  \
# count  1134.000000  1134.000000   1134.000000    1134.000000   1134.000000
# mean     12.751323   520.986772  37235.179894      70.643739      0.906012
# std       8.295081   144.731546  24887.843865      49.026085      0.065958
# min       2.000000   392.000000  13451.000000       8.000000      0.647059
# 25%       6.000000   413.000000  14732.000000      36.000000      0.873016
# 50%       8.000000   429.500000  15839.500000      52.000000      0.916667
# 75%      24.000000   716.000000  65913.000000      86.000000      0.947368
# max      24.000000   728.000000  72888.000000     244.000000      1.000000
#
#        label_freq_rank  raw_image_breadth  norm_image_breadth     num_imgs  \
# count      1134.000000        1134.000000         1134.000000  1134.000000
# mean          2.000000       20782.041446         8526.291887    32.259259
# std           0.816857       58777.547346        11859.383334    20.576505
# min           1.000000         232.000000          232.000000     4.000000
# 25%           1.000000        3432.000000         2094.000000    17.000000
# 50%           2.000000        5588.000000         3541.000000    24.000000
# 75%           3.000000        9247.000000         8112.750000    41.000000
# max           3.000000      431587.000000        86604.000000   104.000000
#
#            min_img      max_img  num_adopters  prop_adopters
# count  1134.000000  1134.000000   1134.000000    1134.000000
# mean    524.970018   924.404762     11.560847       0.925705
# std     324.392412   312.027789      7.405974       0.104294
# min       1.000000   142.000000      2.000000       0.541667
# 25%     229.000000   751.000000      6.000000       0.875000
# 50%     518.000000   864.000000      8.000000       1.000000
# 75%     736.000000  1173.000000     20.000000       1.000000
# max    1351.000000  1499.000000     24.000000       1.000000

# %%
# unique value of a column
columns_name = df.columns
indexs_name = df.index
def cal_unique(df, column_name):
    labels, counts = np.unique(df[column_name], return_counts=True)
    return labels, counts

# %%
# return a dict which associate (label : a list of definitions)
def extract_def(df, labels):
    def_dict = {}
    for label in labels:
        def_values = df[df['label'] == label].definition.values
        if len(def_values) > 0:
            def_dict[label] = (def_values)
    return def_dict

# %%
# return: dict key: 
# n_group value: subdf based on group
def get_data(pwd):
    df = pd.read_csv(pwd, encoding='cp1252')
    # 1. split on the instance_id
    n_uni, n_counts = cal_unique(df, 'instance_id') 
    df_n = [df[df['instance_id'] == n] for n in n_uni]
    # 2. split on labels
    label_list, label_counts = cal_unique(df, 'label')
    # Structure: 
    # one df_sub = dict{label:([ def1, def2, def3...], success_rate)}
    # whole dict -> different dicts
    df_dict = {}
    for idx_n, df_sub in enumerate(df_n):
        key = n_uni[idx_n]
        df_dict[key] = extract_def(df_sub, label_list)
    return df_dict

# %% [markdown]
# ## Calculate Distance

# %%
# For each label in each social group (instance_id), 
# get the word embedding of each word in the definition,  
# and calculate the average pairwise embedding between the definitions of each subject.

if __name__ == '__main__':
    # data_dir = sys.argv[1]
    data_dir = '/Users/lidanyang/Desktop/intensional-and-extensional-category-convergence/data/final_def_data_FULL.csv'
    df_dict = get_data(data_dir)
    # glove_dir = sys.argv[2]
    glove_dir = '/Users/lidanyang/Desktop/intensional-and-extensional-category-convergence/data'
    gloves = load_glove(glove_dir)

    summay = []
    for instance_id in df_dict.keys():
        df_instance_id = df_dict[instance_id]
        for label in df_instance_id.keys():
            label_defs = df_instance_id[label]
            vec = []
            for label_def in label_defs:
                # skip nan value
                try:
                    good_words = tokenizer(label_def)
                except BaseException:
                    continue
                try:
                    centriod_vector = wv_centroid(good_words, gloves)
                    vec.append(centriod_vector)
                except:
                    continue
            count, dis = 0, 0
            for v1, v2 in combinations(vec, 2):
                count += 1
                dis += wv_dis(v1, v2)
            avg_dis = dis / count
            for label_def, v in zip(label_defs, vec):
                summay.append((instance_id, label, avg_dis))

    df_dis = pd.DataFrame(summay,columns=['instance_id','label','distance'])
# Out:
# /Users/lidanyang/Desktop/convergence experiment/nlp_funcs.py:212: RuntimeWarning: invalid value encountered in true_divide
#   return v_sum / count

# %%
dfa = df[['instance_id','label','success_rate','total_success','raw_image_breadth','norm_image_breadth','num_imgs','N']].drop_duplicates()
dfb = df_dis.drop_duplicates()
df2 = pd.merge(dfa, dfb, on=['instance_id','label'])
df2.to_csv('FULL_dis.csv', index=True)
df2
# Out:
#      instance_id   label  success_rate  total_success  raw_image_breadth  \
# 0            400   space      1.000000             44              16030
# 1            400    wide      0.888889             16              31482
# 2            400       x      0.833333             20             162606
# 3            401  anthea      1.000000             16               3452
# 4            401    crab      1.000000             16               1954
# ..           ...     ...           ...            ...                ...
# 144          432    crab      0.948718             74              14408
# 145          432    kiss      0.791667             38              11246
# 146          433    crab      0.833333             50               2492
# 147          433    flat      0.880000             44               4211
# 148          433    frog      0.800000             24               4278
#
#      norm_image_breadth  num_imgs  N  distance
# 0                 16030        22  2  4.398674
# 1                 31482         8  2       NaN
# 2                 86604        10  2  6.553489
# 3                  3452         8  2  1.890510
# 4                  1954         8  2  1.970918
# ..                  ...       ... ..       ...
# 144               12625        36  8  4.696151
# 145               11246        19  8  4.349132
# 146                2492        25  8  6.726773
# 147                4211        20  8       NaN
# 148                1544        11  8  4.850275
#
# [149 rows x 9 columns]

# %%
#null value
df2[df2.distance.isnull()]
# Out:
#      instance_id   label  success_rate  total_success  raw_image_breadth  \
# 1            400    wide      0.888889             16              31482
# 20           407   kickb      1.000000             16               3755
# 23           409   woman      1.000000             10                574
# 27           716   bunny      0.767857             86              44816
# 29           716    frog      0.916667            110               5758
# 34           718    frog      0.929577            132               4152
# 35           718  rabbit      0.928571             52               2469
# 56           414    lift      0.821429             46               8366
# 70           419    crab      0.970588             66               8755
# 127          426  kissin      0.888889             64               8498
# 147          433    flat      0.880000             44               4211
#
#      norm_image_breadth  num_imgs   N  distance
# 1                 31482         8   2       NaN
# 20                 3755         8   2       NaN
# 23                  574         5   2       NaN
# 27                44816        41  24       NaN
# 29                 2235        52  24       NaN
# 34                 1494        59  24       NaN
# 35                 2469        24  24       NaN
# 56                 2301        23   6       NaN
# 70                 5838        31   6       NaN
# 127                8498        31   8       NaN
# 147                4211        20   8       NaN

# %% [markdown]
# ## Correlation
#
# Average distance (inversed intensional consensus); Average coordination success; Overall diversity of related images

# %%
df_corr = df2[['distance', 'success_rate','total_success','raw_image_breadth','norm_image_breadth','num_imgs','N']]
df_corr.corr()
# Out:
#                     distance  success_rate  total_success  raw_image_breadth  \
# distance            1.000000      0.049803      -0.009844           0.248103
# success_rate        0.049803      1.000000      -0.085103          -0.101507
# total_success      -0.009844     -0.085103       1.000000          -0.074650
# raw_image_breadth   0.248103     -0.101507      -0.074650           1.000000
# norm_image_breadth -0.066966     -0.296449      -0.095346           0.369116
# num_imgs           -0.012041     -0.084295       0.994097          -0.073101
# N                   0.008952     -0.175949       0.820390          -0.008161
#
#                     norm_image_breadth  num_imgs         N
# distance                     -0.066966 -0.012041  0.008952
# success_rate                 -0.296449 -0.084295 -0.175949
# total_success                -0.095346  0.994097  0.820390
# raw_image_breadth             0.369116 -0.073101 -0.008161
# norm_image_breadth            1.000000 -0.093374 -0.076318
# num_imgs                     -0.093374  1.000000  0.816513
# N                            -0.076318  0.816513  1.000000

# %%
df_corr_2 = df_corr[df_corr['N'] == 2]
df_corr_2.corr()
# Out:
#                     distance  success_rate  total_success  raw_image_breadth  \
# distance            1.000000      0.066300      -0.140185           0.476256
# success_rate        0.066300      1.000000      -0.178357          -0.156217
# total_success      -0.140185     -0.178357       1.000000          -0.070764
# raw_image_breadth   0.476256     -0.156217      -0.070764           1.000000
# norm_image_breadth  0.061350     -0.684486       0.106544           0.524619
# num_imgs           -0.140185     -0.178357       1.000000          -0.070764
# N                        NaN           NaN            NaN                NaN
#
#                     norm_image_breadth  num_imgs   N
# distance                      0.061350 -0.140185 NaN
# success_rate                 -0.684486 -0.178357 NaN
# total_success                 0.106544  1.000000 NaN
# raw_image_breadth             0.524619 -0.070764 NaN
# norm_image_breadth            1.000000  0.106544 NaN
# num_imgs                      0.106544  1.000000 NaN
# N                                  NaN       NaN NaN

# %%
df_corr_6 = df_corr[df_corr['N'] == 6]
df_corr_6.corr()
# Out:
#                     distance  success_rate  total_success  raw_image_breadth  \
# distance            1.000000      0.096524      -0.149833           0.216160
# success_rate        0.096524      1.000000       0.290001          -0.244338
# total_success      -0.149833      0.290001       1.000000          -0.120633
# raw_image_breadth   0.216160     -0.244338      -0.120633           1.000000
# norm_image_breadth -0.142739     -0.211362      -0.244675           0.267166
# num_imgs           -0.161531      0.272363       0.992115          -0.147229
# N                        NaN           NaN            NaN                NaN
#
#                     norm_image_breadth  num_imgs   N
# distance                     -0.142739 -0.161531 NaN
# success_rate                 -0.211362  0.272363 NaN
# total_success                -0.244675  0.992115 NaN
# raw_image_breadth             0.267166 -0.147229 NaN
# norm_image_breadth            1.000000 -0.261583 NaN
# num_imgs                     -0.261583  1.000000 NaN
# N                                  NaN       NaN NaN

# %%
df_corr_8 = df_corr[df_corr['N'] == 8]
df_corr_8.corr()
# Out:
#                     distance  success_rate  total_success  raw_image_breadth  \
# distance            1.000000      0.010293      -0.012533           0.147998
# success_rate        0.010293      1.000000       0.110624           0.008537
# total_success      -0.012533      0.110624       1.000000          -0.094607
# raw_image_breadth   0.147998      0.008537      -0.094607           1.000000
# norm_image_breadth -0.153598     -0.401944      -0.026614           0.297665
# num_imgs            0.006712      0.140701       0.953074          -0.073870
# N                        NaN           NaN            NaN                NaN
#
#                     norm_image_breadth  num_imgs   N
# distance                     -0.153598  0.006712 NaN
# success_rate                 -0.401944  0.140701 NaN
# total_success                -0.026614  0.953074 NaN
# raw_image_breadth             0.297665 -0.073870 NaN
# norm_image_breadth            1.000000  0.015107 NaN
# num_imgs                      0.015107  1.000000 NaN
# N                                  NaN       NaN NaN

# %%
df_corr_24 = df_corr[df_corr['N'] == 24]
df_corr_24.corr()
# Out:
#                     distance  success_rate  total_success  raw_image_breadth  \
# distance            1.000000      0.457499       0.105454          -0.121587
# success_rate        0.457499      1.000000       0.028347          -0.212164
# total_success       0.105454      0.028347       1.000000          -0.228318
# raw_image_breadth  -0.121587     -0.212164      -0.228318           1.000000
# norm_image_breadth -0.487909     -0.728630      -0.034264           0.441745
# num_imgs            0.078637     -0.002706       0.995301          -0.196571
# N                        NaN           NaN            NaN                NaN
#
#                     norm_image_breadth  num_imgs   N
# distance                     -0.487909  0.078637 NaN
# success_rate                 -0.728630 -0.002706 NaN
# total_success                -0.034264  0.995301 NaN
# raw_image_breadth             0.441745 -0.196571 NaN
# norm_image_breadth            1.000000  0.006466 NaN
# num_imgs                      0.006466  1.000000 NaN
# N                                  NaN       NaN NaN
